# %%
import pandas as pd
import numpy as np

# %%
file = '../DATA/경기도행정구역경계.json'
file1 = '../DATA/repo.json'

# %%
boundaryDF = pd.read_json(file)

# %%
boundaryDF['features']
# Out:
# 0     {'type': 'Feature', 'properties': {'code': 313...
# 1     {'type': 'Feature', 'properties': {'code': 313...
# 2     {'type': 'Feature', 'properties': {'code': 313...
# 3     {'type': 'Feature', 'properties': {'code': 312...
# 4     {'type': 'Feature', 'properties': {'code': 312...
# 5     {'type': 'Feature', 'properties': {'code': 312...
# 6     {'type': 'Feature', 'properties': {'code': 312...
# 7     {'type': 'Feature', 'properties': {'code': 312...
# 8     {'type': 'Feature', 'properties': {'code': 312...
# 9     {'type': 'Feature', 'properties': {'code': 312...
# 10    {'type': 'Feature', 'properties': {'code': 312...
# 11    {'type': 'Feature', 'properties': {'code': 312...
# 12    {'type': 'Feature', 'properties': {'code': 311...
# 13    {'type': 'Feature', 'properties': {'code': 311...
# 14    {'type': 'Feature', 'properties': {'code': 311...
# 15    {'type': 'Feature', 'properties': {'code': 311...
# 16    {'type': 'Feature', 'properties': {'code': 311...
# ...

# %%
def addKey(entry):
    entry.setdefault('code', [])

# %%
boundaryDF['features'].apply(addKey)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# Name: features, dtype: object

# %%
boundaryDF1 = pd.json_normalize(boundaryDF['features'], meta=['type'])

# %%
boundaryDF1
# Out:
#        type  properties.code properties.name  properties.name_eng  \
# 0   Feature            31380             양평군       Yangpyeong-gun
# 1   Feature            31370             가평군         Gapyeong-gun
# 2   Feature            31350             연천군        Yeoncheon-gun
# 3   Feature            31280             여주시             Yeoju-si
# 4   Feature            31270             포천시            Pocheonsi
# 5   Feature            31260             양주시             Yangjusi
# 6   Feature            31250             광주시              Gwangju
# 7   Feature            31240             화성시           Hwaseongsi
# 8   Feature            31230             김포시             Gimpo-si
# 9   Feature            31220             안성시           Anseong-si
# 10  Feature            31210             이천시            Icheon-si
# 11  Feature            31200             파주시              Paju-si
# 12  Feature            31193          용인시수지구       Yonginsisujigu
# ...

# %%
boundaryDF1['geometry.coordinates']
# Out:
# 0     [[[127.56113535909492, 37.6256560539258], [127...
# 1     [[[127.44780328408541, 38.048238751068475], [1...
# 2     [[[127.1114029794941, 38.289324698353205], [12...
# 3     [[[127.40276739880215, 37.41856433413549], [12...
# 4     [[[127.18150182398624, 38.181927191525546], [1...
# 5     [[[126.97545924731331, 37.93928140597955], [12...
# 6     [[[127.30923294884336, 37.5135706079458], [127...
# 7     [[[126.92946761531998, 37.275967848758626], [1...
# 8     [[[126.67862254618308, 37.697305342702336], [1...
# 9     [[[127.4921007211045, 37.04995601187854], [127...
# 10    [[[127.44459662819855, 37.35562085049101], [12...
# 11    [[[126.8029965558113, 37.989251239637596], [12...
# 12    [[[127.03004539569396, 37.36932312139811], [12...
# 13    [[[127.09199113357242, 37.295585212583866], [1...
# 14    [[[127.34092967480524, 37.26770614318737], [12...
# 15    [[[127.16683184366129, 37.57672487388627], [12...
# 16    [[[127.04377994345505, 37.41281928664435], [12...
# ...

# %%
boundaryDF1['geometry.coordinates'][0]
# Out:
# [[[127.56113535909492, 37.6256560539258],
#   [127.57290963929243, 37.61087369350498],
#   [127.56366973908277, 37.5842624297699],
#   [127.52226606559191, 37.5828628697518],
#   [127.50048767007603, 37.569036373178626],
#   [127.47687473909174, 37.574448241913856],
#   [127.47565866803647, 37.60512112601634],
#   [127.44699730711024, 37.644975847411644],
#   [127.4272349102434, 37.66284420898682],
#   [127.40156700708162, 37.64806970784708],
#   [127.3732642199939, 37.6453987554284],
#   [127.3542931884407, 37.6250006376975],
#   [127.34360057873045, 37.588997440929354],
#   [127.31002843450217, 37.53523876142835],
#   [127.30923294884336, 37.5135706079458],
#   [127.32809611134748, 37.53133849534739],
#   [127.3663244453597, 37.52716845880826],
#   [127.38286320755414, 37.50147517965334],
#   [127.39046783039153, 37.47413422098595],
#   [127.37490698722792, 37.455072688441305],
#   [127.39174400683049, 37.4256483411369],
#   [127.40276739880215, 37.41856433413549],
# ...

# %%
pd.DataFrame(boundaryDF1['geometry.coordinates'][0][0])
# Out:
#              0          1
# 0   127.561135  37.625656
# 1   127.572910  37.610874
# 2   127.563670  37.584262
# 3   127.522266  37.582863
# 4   127.500488  37.569036
# 5   127.476875  37.574448
# 6   127.475659  37.605121
# 7   127.446997  37.644976
# 8   127.427235  37.662844
# 9   127.401567  37.648070
# 10  127.373264  37.645399
# 11  127.354293  37.625001
# 12  127.343601  37.588997
# 13  127.310028  37.535239
# 14  127.309233  37.513571
# 15  127.328096  37.531338
# 16  127.366324  37.527168
# 17  127.382863  37.501475
# 18  127.390468  37.474134
# 19  127.374907  37.455073
# 20  127.391744  37.425648
# 21  127.402767  37.418564
# 22  127.425005  37.436700
# 23  127.481790  37.420844
# 24  127.510153  37.436996
# 25  127.525012  37.431920
# 26  127.539106  37.408493
# 27  127.605287  37.416970
# 28  127.637540  37.410656
# 29  127.649184  37.402043
# 30  127.669768  37.408844
# 31  127.710715  37.407366
# 32  127.703474  37.371054
# 33  127.761654  37.364219
# ...

# %%
DF = pd.read_json(file1)

# %%
DF
# Out:
#      id                   node_id                    name  \
# 0     1      MDEwOlJlcG9zaXRvcnkx                    grit
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==               merb-core
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==                rubinius
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==                     god
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==               jsawesome
# ..  ...                       ...                     ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=      acts_as_geocodable
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=           acts_as_money
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=        calendar_builder
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  clear_empty_attributes
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=           css_naked_day
#
#                                 full_name  private  \
# 0                            mojombo/grit    False
# 1                        wycats/merb-core    False
# 2                       rubinius/rubinius    False
# 3                             mojombo/god    False
# ...

# %%
DF['owner']
# Out:
# 0     {'login': 'mojombo', 'id': 1, 'node_id': 'MDQ6...
# 1     {'login': 'wycats', 'id': 4, 'node_id': 'MDQ6V...
# 2     {'login': 'rubinius', 'id': 317747, 'node_id':...
# 3     {'login': 'mojombo', 'id': 1, 'node_id': 'MDQ6...
# 4     {'login': 'vanpelt', 'id': 17, 'node_id': 'MDQ...
#                             ...
# 95    {'login': 'collectiveidea', 'id': 128, 'node_i...
# 96    {'login': 'collectiveidea', 'id': 128, 'node_i...
# 97    {'login': 'collectiveidea', 'id': 128, 'node_i...
# 98    {'login': 'collectiveidea', 'id': 128, 'node_i...
# 99    {'login': 'collectiveidea', 'id': 128, 'node_i...
# Name: owner, Length: 100, dtype: object

# %%
pd.json_normalize(DF['owner'])
# Out:
#              login      id                           node_id  \
# 0          mojombo       1                      MDQ6VXNlcjE=
# 1           wycats       4                      MDQ6VXNlcjQ=
# 2         rubinius  317747  MDEyOk9yZ2FuaXphdGlvbjMxNzc0Nw==
# 3          mojombo       1                      MDQ6VXNlcjE=
# 4          vanpelt      17                      MDQ6VXNlcjE3
# ..             ...     ...                               ...
# 95  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 96  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 97  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 98  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 99  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
#
#                                            avatar_url gravatar_id  \
# 0      https://avatars0.githubusercontent.com/u/1?v=4
# 1      https://avatars0.githubusercontent.com/u/4?v=4
# 2   https://avatars2.githubusercontent.com/u/31774...
# ...
